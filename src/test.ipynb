# %%
from MultipleLinearRegression import MultipleLinearRegression
import numpy as np
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv(r"../data/Income.csv")

print(df.columns.tolist())
print(df.head())
# Out:
# ['age', 'experience', 'income']
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
# Separate features (X) and target (y)
X = df.drop(columns=['income']).values  # drop Income column to get features
y = df['income'].values  # Income column is the target

# Prepare feature names 
feature_names = df.drop(columns=['income']).columns.tolist()

# %%
# Create the model
model = MultipleLinearRegression()
model.fit(X, y)

# %%
# Fit the model on ALL features
model.fit(X, y)

# %%
# Plot results
# %matplotlib widget
model.plot(X, y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Plotting complete

# %%
# Predict (using training data)
y_pred = model.predict(X)

# %%
# Evaluate the full model
print("\nOverall Model ANOVA Table:\n")
anova_table = model.anova(X, y, feature_names)  # Feature-by-feature modified version
# Out:
# Overall Model ANOVA Table:
#
# ANOVA for Feature: age
#        Source            SS  df            MS        F   p-value
# 0  Regression  3.833315e+08   1  3.833315e+08  7.11306  0.015713
# 1    Residual  9.700420e+08  18  5.389122e+07      NaN       NaN
# 2       Total  1.353373e+09  19           NaN      NaN       NaN
# ANOVA for Feature: experience
#        Source            SS  df            MS          F       p-value
# 0  Regression  1.311016e+09   1  1.311016e+09  557.11806  5.421511e-15
# 1    Residual  4.235778e+07  18  2.353210e+06        NaN           NaN
# 2       Total  1.353373e+09  19           NaN        NaN           NaN

# %%
print("\nOverall Model Hypothesis Test Table:\n")
hypothesis_table = model.hypothesis_test(X, y, feature_names)
# Out:
# Overall Model Hypothesis Test Table:
#
# Hypothesis Test for Feature: age
#   Coefficient      Estimate    Std Error  t-statistic   p-value
# 0   Intercept  22975.161864  6858.549387     3.349857  0.003566
# 1         age    447.927822   167.949926     2.667032  0.015713
# Hypothesis Test for Feature: experience
#   Coefficient      Estimate   Std Error  t-statistic       p-value
# 0   Intercept  28248.446782  630.508544    44.802639  0.000000e+00
# 1  experience   2014.040842   85.328607    23.603348  5.551115e-15
